# %% [markdown]
# **TOP IMDB Action movies**

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup as soup

from requests import get
url = get("https://www.imdb.com/search/title/?genres=action&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=BG1CG1TDYDB4FQYYS55B&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1")
request = url.text
request

data = soup(request, 'html.parser')
divs = data.find_all('div', {'class': 'lister-item mode-advanced'})

# %%
movie_name = []
description = []
release_date = []
director_name = []
rating = []
duration = []
votes = []
stars = []
budget = []
genre = []

# %%
# movie_name
for div in divs:
    content = div.find('div', {'class': 'lister-item-content'})
    titles = content.find('a').get_text()
    movie_name.append(titles)

# rating
for div in divs:
    contents = div.find('div', {'class': 'lister-item-content'})
    rate = contents.find('strong').get_text()
    rating.append(rate)

# duration
for div in divs:
    contents = div.find('div', {'class': 'lister-item-content'})
    time = contents.find('span', {'class': 'runtime'}).get_text()[:3]
    duration.append(int(time))

# release_date
for div in divs:
    content1 = div.find('span',{'class': 'lister-item-year text-muted unbold'}).text[1:5]
    release_date.append(content1)

# votes
for div in divs:
    contents = div.find('div', {'class': 'lister-item-content'})
    vote = contents.find('span', {'name': 'nv'}).get_text().replace(',','')
    if vote == "[]":
        vote = None
    else:
        votes.append(int(vote))

# director_name
for div in divs:
    contents = div.find('div', {'class': 'lister-item-content'})
    find_p = contents.find_all('p')[2]
    find_a = find_p.find_all('a')[0].get_text()
    director_name.append(find_a)

#genre
for div in divs:
    content = div.find('div', {'class': 'lister-item-content'})
    gernes = content.find('p')
    #print(gernes)
    ger = gernes.find('span', {'class' : "genre"}).get_text()
    genre.append(ger)

# Stars
for div in divs:
    contents = div.find('div', {'class': 'lister-item-content'})
    find_p = contents.find_all('p')[2]
    find_a = find_p.find_all('a')[1:]
    for e in find_a:
        stars.append(e.get_text())

# %%
data_df = {}
data_df["movie_name"] = movie_name
data_df["duration"] = duration
# data_df["description"] = description
data_df["director_name"] = director_name
data_df["release_date"] = release_date
data_df["votes"] = votes
# data_df["stars"] = stars

for key in data_df:
 
    print(len(data_df[key]), key)

df = pd.DataFrame(data_df)
print (df)
# Out:
# 50 movie_name
# 50 duration
# 50 director_name
# 50 release_date
# 50 votes
#                                      movie_name  duration      director_name  \
# 0                               The Dark Knight       152  Christopher Nolan
# 1   Der Herr der Ringe: Die Rückkehr des Königs       201      Peter Jackson
# 2                                       Berg II       135       Alper Caglar
# 3                                     Inception       148  Christopher Nolan
# 4             Der Herr der Ringe: Die Gefährten       178      Peter Jackson
# 5            Der Herr der Ringe: Die zwei Türme       179      Peter Jackson
# 6                                        Matrix       136     Lana Wachowski
# 7                   Das Imperium schlägt zurück       124     Irvin Kershner
# 8                              Krieg der Sterne       121       George Lucas
# 9                                      Harakiri       133   Masaki Kobayashi
# 10                           Die sieben Samurai       207     Akira Kurosawa
# 11                                     Ratsasan       170          Ram Kumar
# 12                                    Gladiator       155       Ridley Scott
# 13                              Léon: Der Profi       110         Luc Besson
# 14             Terminator 2: Tag der Abrechnung       137      James Cameron
# 15                                 Vikram Vedha       147            Gayatri
# 16     Dangal: Die Hoffnung auf den großen Sieg       161      Nitesh Tiwari
# 17                   Spider-Man: A New Universe       117    Bob Persichetti
# 18                            Avengers: Endgame       181      Anthony Russo
# 19                       Avengers: Infinity War       149      Anthony Russo
# 20                        The Dark Knight Rises       164  Christopher Nolan
# 21                                       Oldboy       120     Chan-wook Park
# 22                          Prinzessin Mononoke       134     Hayao Miyazaki
# 23                Jäger des verlorenen Schatzes       115   Steven Spielberg
# 24                  Zack Snyder: Justice League       242        Zack Snyder
# 25                        Aliens - Die Rückkehr       137      James Cameron
# 26                 Die Rückkehr der Jedi-Ritter       131   Richard Marquand
# 27                                Lethal Strike       138        Aditya Dhar
# 28                             K.G.F: Chapter 1       156     Prashanth Neel
# 29                  Baahubali 2: The Conclusion       167     S.S. Rajamouli
# 30                                 Vishwaroopam       148       Kamal Haasan
# 31                           Gangs of Wasseypur       321     Anurag Kashyap
# 32                             Paan Singh Tomar       135   Tigmanshu Dhulia
# 33                                      Warrior       140     Gavin O'Connor
# 34                               V wie Vendetta       132     James McTeigue
# 35                                Batman Begins       140  Christopher Nolan
# 36                                   Hera Pheri       156       Priyadarshan
# 37                         Bube Dame König grAS       107        Guy Ritchie
# 38                              Andaz Apna Apna       160  Rajkumar Santoshi
# 39        Indiana Jones und der letzte Kreuzzug       127   Steven Spielberg
# 40                                Stirb langsam       132     John McTiernan
# 41                                          Ran       162     Akira Kurosawa
# 42                                       Sholay       204       Ramesh Sippy
# 43                    Yojimbo - Der Leibwächter       110     Akira Kurosawa
# 44                          Sherlock Holmes Jr.        45      Buster Keaton
# 45                                       Haider       160    Vishal Bhardwaj
# 46                         Logan: The Wolverine       137      James Mangold
# 47                              1 - Nenokkadine       170            Sukumar
# 48                     Rush: Alles für den Sieg       123         Ron Howard
# 49               Le Mans 66 - Gegen jede Chance       152      James Mangold
#
#    release_date    votes
# 0          2008  2329294
# 1          2003  1657517
# 2          2016   105546
# 3          2010  2090114
# 4          2001  1677215
# 5          2002  1498876
# 6          1999  1693370
# 7          1980  1169118
# 8          1977  1241131
# 9          1962    43514
# 10         1954   318637
# 11         2018    26446
# 12         2000  1353590
# 13         1994  1045824
# 14         1991  1002940
# 15         2017    29211
# 16         2016   159442
# 17         2018   387319
# 18         2019   842186
# 19         2018   855568
# 20         2012  1530034
# 21         2003   521082
# 22         1997   347953
# 23         1981   890394
# 24         2021   202244
# 25         1986   657626
# 26         1983   958191
# 27         2018    44004
# 28         2018    37978
# 29         2017    76168
# 30         2013    38855
# 31         2012    83367
# 32         2012    33440
# 33         2011   439219
# 34         2005  1040372
# 35         2005  1319944
# 36         2000    57583
# 37         1998   539743
# 38         1994    49553
# 39         1989   696972
# 40         1988   798698
# 41         1985   113920
# 42         1975    51604
# 43         1961   112504
# 44         1924    42787
# 45         2014    50697
# 46         2017   656381
# 47         2014    43259
# 48         I) (   436439
# 49         2019   302343

# %% [markdown]
# ### Exercise 11.2
# Do the same thing as you did for the previous exercise, but now process the text line by line. This is something that you would have to do if you had to process a very long text (as it is the case).

# %%
           
def display_contents_file2(file_name):
    fp = open( file_name )
    while True:
        buffer = fp.readline()             
        if buffer == "":
            break     
        print( buffer )
    fp.close()


def word_count(str):
    
    words = str.split()
    counts = dict()
    for word in words:
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1

    return counts

print( word_count(buffer))
# Out:
# {'[Poems': 1, 'by': 19, 'William': 2, 'Blake': 1, '1789]': 1, 'You': 2, 'can': 19, 'do': 7, 'this': 15, 'SONGS': 4, 'OF': 8, 'INNOCENCE': 3, 'AND': 3, 'EXPERIENCE': 2, 'and': 169, 'THE': 27, 'BOOK': 3, 'of': 131, 'THEL': 4, 'INTRODUCTION': 2, 'Piping': 2, 'down': 15, 'the': 351, 'valleys': 4, 'wild,': 3, 'songs': 3, 'pleasant': 4, 'glee,': 1, 'On': 9, 'a': 107, 'cloud': 5, 'I': 122, 'saw': 7, 'child,': 5, 'And': 168, 'he': 30, 'laughing': 3, 'said': 3, 'to': 92, 'me:': 3, '"Pipe': 1, 'song': 3, 'about': 1, 'Lamb!"': 1, 'So': 10, 'piped': 1, 'with': 59, 'merry': 5, 'cheer.': 1, '"Piper,': 2, 'pipe': 1, 'that': 21, 'again;"': 1, 'piped:': 1, 'wept': 7, 'hear.': 3, '"Drop': 1, 'thy': 28, 'pipe,': 1, 'happy': 18, 'pipe;': 1, 'Sing': 2, 'cheer:!"': 1, 'sang': 2, 'same': 1, 'again,': 1, 'While': 10, 'joy': 12, 'sit': 9, 'thee': 19, 'write': 1, 'In': 25, 'book,': 1, 'all': 28, 'may': 5, 'read."': 1, "vanish'd": 1, 'from': 28, 'my': 72, 'sight;': 1, "pluck'd": 1, 'hollow': 3, 'reed,': 1, 'made': 6, 'rural': 1, 'pen,': 1, "stain'd": 1, 'water': 2, 'clear,': 1, 'wrote': 1, 'Every': 2, 'child': 8, 'SHEPHERD': 1, 'How': 9, 'sweet': 11, 'is': 45, "Shepherd's": 1, 'lot!': 1, 'From': 4, 'morn': 4, 'evening': 5, 'stays;': 1, 'He': 20, 'shall': 15, 'follow': 1, 'his': 49, 'sheep': 2, 'day,': 9, 'tongue': 3, 'be': 20, 'filled': 3, 'praise.': 1, 'For': 10, 'hears': 3, "lambs'": 1, 'innocent': 4, 'call,': 2, "ewes'": 1, 'tender': 9, 'reply;': 1, 'watching': 1, 'while': 3, 'they': 30, 'are': 21, 'in': 115, 'peace,': 2, 'know': 8, 'when': 10, 'their': 34, 'Shepherd': 1, 'nigh.': 1, 'ECHOING': 1, 'GREEN': 1, 'The': 61, 'sun': 6, 'does': 13, 'arise,': 3, 'make': 5, 'skies;': 1, 'bells': 1, 'ring': 1, 'To': 18, 'welcome': 4, 'Spring;': 1, 'skylark': 2, 'thrush,': 1, 'birds': 8, 'bush,': 1, 'louder': 1, 
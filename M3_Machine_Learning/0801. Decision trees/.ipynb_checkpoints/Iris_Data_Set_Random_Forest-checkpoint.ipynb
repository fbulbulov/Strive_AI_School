# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
from sklearn import datasets
from sklearn.decomposition import PCA

# import some data to play with
iris = datasets.load_iris()
X = iris.data  # we only take the first two features.
y = iris.target

df=pd.DataFrame(iris.data)
df["class"]=iris.target
df
# Out:
#        0    1    2    3  class
# 0    5.1  3.5  1.4  0.2      0
# 1    4.9  3.0  1.4  0.2      0
# 2    4.7  3.2  1.3  0.2      0
# 3    4.6  3.1  1.5  0.2      0
# 4    5.0  3.6  1.4  0.2      0
# ..   ...  ...  ...  ...    ...
# 145  6.7  3.0  5.2  2.3      2
# 146  6.3  2.5  5.0  1.9      2
# 147  6.5  3.0  5.2  2.0      2
# 148  6.2  3.4  5.4  2.3      2
# 149  5.9  3.0  5.1  1.8      2
#
# [150 rows x 5 columns]

# %%
df['species'] = np.array([iris.target_names[i] for i in iris.target])
sns.pairplot(df, hue='species')
# Out:
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
X_train,X_test, y_train, y_test=train_test_split(X,y,random_state=0,train_size=0.8)
clf_2= DecisionTreeClassifier(random_state=0,criterion="gini",splitter="random",max_depth=4,min_samples_leaf=5)
clf_2.fit(X_train,y_train)
y_predict=clf_2.predict(X_test)
metrics.accuracy_score(y_predict, y_test)
# Out:
# 1.0

# %%
clf_1 = DecisionTreeClassifier(random_state=0,criterion="entropy")
clf_1.fit(X,y)

cross_val_score(clf_1, X, y, cv=5)
# Out:
# array([0.96666667, 0.96666667, 0.9       , 0.93333333, 1.        ])

# %%
import graphviz
from sklearn import tree
dot_data = tree.export_graphviz(clf_2, out_file=None, feature_names=iris.feature_names, class_names=iris.target_names, filled=True)
graph = graphviz.Source(dot_data, format="png") 
graph

# %%
from dtreeviz.trees import dtreeviz
viz = dtreeviz(clf_1, X, y, target_name="target", feature_names=iris.feature_names,class_names=list(iris.target_names))

viz

# %% [markdown]
# ## Random Forrest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
random_f = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=0)

# %%
random_f.fit(X_train, y_train)
# Out:
# RandomForestClassifier(oob_score=True, random_state=0)

# %%
predicted_y = rf.predict(X_test)
accuracy = metrics.accuracy_score(y_test, predicted_y)
print(f'Mean accuracy score: {accuracy:.3}')
# Out:
# Mean accuracy score: 1.0

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = pd.DataFrame(confusion_matrix(y_test, predicted_y), columns=iris.target_names, index=iris.target_names)
sns.heatmap(cm, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Plotting

# %%
import graphviz as graphiz
from sklearn import tree

dot_data = tree.export_graphviz(clf_1, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("iris")
# Out:
# 'iris.pdf'

# %%
dot_data = tree.export_graphviz(clf_1,out_file=None,feature_names=iris.feature_names,  class_names=iris.target_names,  filled=True, rounded=True,  special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=fb7530d9-a137-4e94-b4b0-3ca068a44035' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
